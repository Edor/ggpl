# %% [markdown]
# Esercitazione
# =======
# Lezione 1
# ----------
# Questa è la prima esercitazione!

# %%
from larlib import *
import numpy
# Out:
# Evaluating fenvs.py..
# ...fenvs.py imported in 0.006706 seconds

# %%
VIEW(CUBE(1))
# Out:
# <pyplasm.xgepy.Hpc; proxy of <Swig Object of type 'std::shared_ptr< Hpc > *' at 0x7fb2f10a2540> >

# %% [markdown]
# ![cubo1.png](attachment:cubo1.png)

# %% [markdown]
# Integrale di volume sul dominio $D$ del monomio $x^\alpha y^\beta z^\gamma$
# $$\int_D x^\alpha y^\beta z^\gamma dV$$

# %%
# La riga sotto è volutamente commentata. Il suo output è troppo lungo ai fini dell'assignment

# help(numpy)

# %%
# Vedo se funzionano gli array, stampando un output per test

a1 = numpy.array([1,2,3,4])
a1
# Out:
# array([1, 2, 3, 4])

# %%
# Genero 100 punti nello spazio [0;100]^2 

listaPunti = []
for x in range (0,10,1):
    for y in range (0,10,1):
        listaPunti.append((randint(0,101),randint(0,101)))
listaPunti
# Out:
# [(65, 44),
#  (71, 37),
#  (67, 17),
#  (15, 76),
#  (68, 30),
#  (38, 2),
#  (65, 65),
#  (2, 41),
#  (51, 68),
#  (50, 40),
#  (37, 29),
#  (47, 67),
#  (68, 39),
#  (91, 12),
#  (71, 50),
#  (42, 74),
#  (44, 29),
#  (82, 50),
#  (26, 54),
#  (26, 29),
#  (42, 1),
#  (3, 75),
#  (52, 72),
#  (8, 73),
#  (87, 92),
#  (86, 36),
#  (61, 14),
#  (46, 7),
#  (36, 53),
#  (36, 20),
#  (76, 59),
#  (75, 59),
#  (40, 19),
#  (89, 87),
#  (18, 27),
#  (43, 59),
#  (81, 56),
#  (2, 58),
#  (33, 77),
#  (45, 40),
#  (3, 90),
#  (62, 100),
#  (22, 6),
#  (43, 0),
#  (58, 55),
#  (37, 73),
#  (29, 17),
#  (11, 24),
#  (29, 41),
#  (4, 33),
#  (31, 76),
#  (48, 45),
#  (7, 67),
#  (62, 17),
#  (72, 29),
#  (91, 92),
#  (67, 46),
#  (31, 89),
#  (66, 24),
#  (60, 36),
#  (63, 5),
#  (67, 44),
#  (20, 80),
#  (2, 8),
#  (39, 33),
#  (63, 15),
#  (73, 24),
#  (51, 8),
#  (44, 39),
#  (13, 93),
#  (58, 42),
#  (17, 20),
#  (59, 87),
#  (85, 94),
#  (93, 28),
#  (6, 51),
#  (84, 9),
#  (7, 94),
# ...

# %%
# Creo un modello unendo tutti e 100 i punti in un singolo poliedro. Con un po' di fortuna dovrebbe essere
# un poliedro di forma casuale inscritto nel quadrato di lato 100!

FlistaPunti = []
for x in range (0,len(listaPunti),1):
    FlistaPunti.append(x)

FlistaPunti2=[FlistaPunti]
model=listaPunti,FlistaPunti2

# %%
# Visualizzo l'intero poliedro

VIEW(STRUCT(MKPOLS(model)))
# Out:
# <pyplasm.xgepy.Hpc; proxy of <Swig Object of type 'std::shared_ptr< Hpc > *' at 0x7f99afef4ba0> >

# %% [markdown]
# ![randomcube.png](attachment:randomcube.png)

# %%
# Visualizzo solo il perimetro del poliedro

VIEW(SKEL_1(STRUCT(MKPOLS(model))))
# Out:
# <pyplasm.xgepy.Hpc; proxy of <Swig Object of type 'std::shared_ptr< Hpc > *' at 0x7f99afef47e0> >

# %% [markdown]
# ![randomcube-skel.png](attachment:randomcube-skel.png)

# %%
# Faccio una prova in 3D. Creo una nuova lista di punti.

NL = []
for x in range (0,5,1):
    for y in range (0,5,1):
        for z in range (0,5,1):
            NL.append((randint(0,101), randint(0,101), randint(30,71)))
NL
# Out:
# [(82, 50, 66),
#  (38, 18, 40),
#  (38, 9, 51),
#  (40, 89, 52),
#  (76, 1, 32),
#  (68, 45, 61),
#  (95, 23, 60),
#  (29, 63, 33),
#  (32, 33, 68),
#  (39, 9, 32),
#  (97, 77, 66),
#  (15, 10, 59),
#  (78, 88, 64),
#  (19, 86, 48),
#  (0, 48, 51),
#  (38, 13, 56),
#  (23, 26, 41),
#  (100, 3, 50),
#  (21, 8, 69),
#  (90, 44, 70),
#  (93, 26, 33),
#  (28, 95, 49),
#  (52, 99, 57),
#  (71, 42, 68),
#  (63, 28, 63),
#  (50, 6, 69),
#  (83, 36, 57),
#  (16, 85, 58),
#  (34, 47, 58),
#  (74, 83, 51),
#  (10, 58, 67),
#  (60, 91, 48),
#  (95, 1, 68),
#  (67, 81, 38),
#  (50, 20, 30),
#  (22, 70, 51),
#  (28, 87, 37),
#  (54, 76, 52),
#  (34, 66, 69),
#  (95, 99, 59),
#  (93, 78, 51),
#  (8, 94, 37),
#  (45, 23, 60),
#  (78, 88, 57),
#  (69, 61, 49),
#  (67, 28, 69),
#  (16, 9, 63),
#  (77, 19, 70),
#  (84, 44, 63),
#  (4, 70, 31),
#  (59, 53, 63),
#  (37, 39, 41),
#  (40, 28, 46),
#  (72, 11, 60),
#  (66, 11, 42),
#  (62, 46, 34),
#  (68, 74, 49),
#  (38, 49, 63),
#  (28, 85, 41),
# ...

# %%
FNL = []
for x in range (0,len(NL),1):
    FNL.append(x)

FNL2=[FNL]
model=NL,FNL2

# %%
# Visualizzo il solido

VIEW(STRUCT(MKPOLS(model)))

# %% [markdown]
# Ecco un bellissimo smeraldo :)
# ----------------------------------

# %% [markdown]
# ![solido.png](attachment:solido.png)
