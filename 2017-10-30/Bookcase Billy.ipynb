# %% [markdown]
# La mia libreria Billy...
# =============
# http://www.ikea.com/it/it/catalog/products/00263850/

# %%
from larlib import *
# Out:
# Evaluating fenvs.py..
# ...fenvs.py imported in 0.006448 seconds

# %%
def billy(n,m,k):
    xRithm = [0.7, -15]*n
    xRithm.append(0.7)
    yRithm = [-5, 0.7]*m
    yRithm.append(-1.5)
    yRithm = yRithm[::-1]
    yRithm.append(0.7)
    xVoid = [ -x for x in xRithm ]
    yVoid = [ -y for y in yRithm ]
    zRithm = [k]
    temp1 = PROD([PROD([QUOTE(xRithm), QUOTE(yRithm)]), QUOTE(zRithm)])
    temp2 = PROD([PROD([QUOTE(xVoid), QUOTE(yRithm)]), QUOTE(zRithm)])
    temp3 = PROD([PROD([QUOTE(xRithm), QUOTE(yVoid)]), QUOTE(zRithm)])
    facade = STRUCT([temp1, 
                    temp2, 
                    temp3])
    
    xCoord = (0.7+15)*n + 0.7
    yCoord = (0.7+5)*m + 2.2
    zCoord = 0.7
    backPanel = CUBOID([xCoord, yCoord, zCoord])
    basePanel = CUBOID([xCoord, 1.5, k-0.7])
    BIANCOPANNA = Color4f([0.941,0.863,0.510,1.0])
    return STRUCT([COLOR(BIANCOPANNA),facade, backPanel, basePanel])

# %%
VIEW(billy(1,6,5))

# %% [markdown]
# ![Screenshot%20from%202017-10-30%2016-53-16.png](attachment:Screenshot%20from%202017-10-30%2016-53-16.png)
